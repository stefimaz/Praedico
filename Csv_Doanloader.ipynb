# %%
import pandas as pd

# %%
url = "http://pfref.com/pi/share/YNNiB"

# %%
df = pd.read_html(url, header = 0)
df = df[0]

# %%
df.head()
# Out:
#   Unnamed: 0    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0       Week          Date        NaN        Rec        NaN
# 1          1  September 12          W        1-0          @
# 2          2  September 19          L        1-1        NaN
# 3          3  September 26          L        1-2        NaN
# 4          4     October 3          L        1-3          @
#
#            Unnamed: 5 Scor Scor.1  Offe Offe.1  ... Offe.3 Offe.4  Defe  \
# 0                 Opp   Tm    Opp  1stD  TotYd  ...  RushY     TO  1stD
# 1       Buffalo Bills   23     16    16    252  ...     75    NaN    22
# 2   Las Vegas Raiders   17     26    17    331  ...     39      1    22
# 3  Cincinnati Bengals   10     24    21    342  ...     45      2    12
# 4   Green Bay Packers   17     27    17    282  ...     62      2    23
#
#   Defe.1 Defe.2 Defe.3 Defe.4     Expe   Expe.1   Expe.2
# 0  TotYd  PassY  RushY     TO  Offense  Defense  Sp. Tms
# ...

# %%
df.to_csv('./resources/Pittsburgh_Steelers.csv', index=False)
