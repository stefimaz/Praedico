# %%
import pandas as pd

# %%
url = "http://pfref.com/pi/share/IDiIy"

# %%
df = pd.read_html(url, header = 0)
df = df[0]

# %%
df.head()
# Out:
#   Unnamed: 0    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0       Week          Date        NaN        Rec        NaN
# 1          1  September 12          W        1-0          @
# 2          2  September 19          L        1-1        NaN
# 3          3  September 27          L        1-2          @
# 4          4     October 3          L        1-3        NaN
#
#             Unnamed: 5 Scor Scor.1  Offe Offe.1  ... Offe.3 Offe.4  Defe  \
# 0                  Opp   Tm    Opp  1stD  TotYd  ...  RushY     TO  1stD
# 1      Atlanta Falcons   32      6    24    434  ...    173    NaN    19
# 2  San Francisco 49ers   11     17    18    328  ...    151    NaN    23
# 3       Dallas Cowboys   21     41    12    367  ...     64      2    27
# 4   Kansas City Chiefs   30     42    30    461  ...    103    NaN    31
#
#   Defe.1 Defe.2 Defe.3 Defe.4     Expe   Expe.1   Expe.2
# 0  TotYd  PassY  RushY     TO  Offense  Defense  Sp. Tms
# ...

# %%
df.to_csv('./resources/Philadelphia_Eagles.csv', index=False)
